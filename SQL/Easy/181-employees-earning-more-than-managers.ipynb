# %% [markdown]
# # Employees Earning More Than Their Managers (LeetCode #181)
#
# ## Problem Description
#
# Table: `Employee`
# ```
# +-------------+---------+
# | Column Name | Type    |
# +-------------+---------+
# | id          | int     |
# | name        | varchar |
# | salary      | int     |
# | managerId   | int     |
# +-------------+---------+
# id is the primary key for this table.
# Each row indicates the ID, name, salary of an employee and the ID of their manager.
# ```
#
# Write a solution to find the employees who earn more than their managers.
#
# Return the result table in **any order**.
#
# ### Example
#
# **Input:**
# ```
# Employee table:
# +----+-------+--------+-----------+
# | id | name  | salary | managerId |
# +----+-------+--------+-----------+
# | 1  | Joe   | 70000  | 3         |
# | 2  | Henry | 80000  | 4         |
# | 3  | Sam   | 60000  | Null      |
# | 4  | Max   | 90000  | Null      |
# +----+-------+--------+-----------+
# ```
#
# **Output:**
# ```
# +----------+
# | Employee |
# +----------+
# | Joe      |
# +----------+
# ```
#
# **Explanation:** Joe earns 70000, which is more than his manager Sam (60000).

# %% [markdown]
# ## Approach
#
# **Self Join**
#
# Join the Employee table with itself where:
# - `e1` is the employee
# - `e2` is the manager (matched by `e1.managerId = e2.id`)
#
# Then filter where the employee's salary is greater than the manager's salary.

# %%
# SQL Solution using Self Join
sql_query = """
SELECT e1.name AS Employee
FROM Employee e1
JOIN Employee e2 ON e1.managerId = e2.id
WHERE e1.salary > e2.salary;
"""

print(sql_query)

# %% [markdown]
# ## Alternative Solution (Using Subquery)

# %%
# SQL Solution using Subquery
sql_query_subquery = """
SELECT e.name AS Employee
FROM Employee e
WHERE e.salary > (
    SELECT m.salary 
    FROM Employee m 
    WHERE m.id = e.managerId
);
"""

print(sql_query_subquery)

# %% [markdown]
# ## Complexity Analysis
#
# - **Time Complexity:** O(n²) without indexes, O(n log n) with proper indexing on id.
# - **Space Complexity:** O(n) for the join result.
