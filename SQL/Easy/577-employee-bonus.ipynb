# %% [markdown]
# # Employee Bonus (LeetCode #577)
#
# ## Problem Description
#
# Write a solution to report the name and bonus amount of each employee with a bonus **less than 1000** or who **did not receive any bonus**.
#
# Return the result table in **any order**.
#
# ### Table: Employee
#
# | Column Name | Type    |
# |-------------|---------|
# | empId       | int     |
# | name        | varchar |
# | supervisor  | int     |
# | salary      | int     |
#
# `empId` is the primary key for this table.
#
# ### Table: Bonus
#
# | Column Name | Type |
# |-------------|------|
# | empId       | int  |
# | bonus       | int  |
#
# `empId` is the primary key and foreign key referencing Employee.empId.
#
# **Example:**
#
# Input:
# ```
# Employee table:
# | empId | name   | supervisor | salary |
# |-------|--------|------------|--------|
# | 3     | Brad   | null       | 4000   |
# | 1     | John   | 3          | 1000   |
# | 2     | Dan    | 3          | 2000   |
# | 4     | Thomas | 3          | 4000   |
#
# Bonus table:
# | empId | bonus |
# |-------|-------|
# | 2     | 500   |
# | 4     | 2000  |
# ```
#
# Output:
# ```
# | name | bonus |
# |------|-------|
# | Brad | null  |
# | John | null  |
# | Dan  | 500   |
# ```

# %% [markdown]
# ## Approach
#
# This problem requires:
# 1. **LEFT JOIN** - To include employees without bonus entries (they'll have NULL bonus)
# 2. **Proper NULL handling** - Employees without bonus have NULL, not 0
#
# **Key Insight:**
# - We need employees where `bonus < 1000` OR `bonus IS NULL`
# - Using **AND** instead of **OR** would return nothing (can't be both < 1000 AND NULL)
# - A LEFT JOIN ensures employees missing from Bonus table are included with NULL values

# %%
# SQL Solution
sql_query = """
SELECT 
    e.name,
    b.bonus
FROM Employee e
LEFT JOIN Bonus b
ON e.empId = b.empId
WHERE b.bonus < 1000 OR b.bonus IS NULL;
"""

# %% [markdown]
# ## Alternative Solution using IFNULL/COALESCE
#
# Another approach treats NULL as 0 using IFNULL:

# %%
# Alternative SQL Solution using IFNULL
sql_query_alt = """
SELECT 
    e.name,
    b.bonus
FROM Employee e
LEFT JOIN Bonus b
ON e.empId = b.empId
WHERE IFNULL(b.bonus, 0) < 1000;
"""

# %% [markdown]
# ## Complexity Analysis
#
# - **Time Complexity:** O(n + m) where n is employees and m is bonus entries
# - **Space Complexity:** O(k) where k is the number of qualifying employees
