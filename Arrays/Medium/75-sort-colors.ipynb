# %% [markdown]
# # Sort Colors (LeetCode #75)
#
# ## Problem Description
#
# Given an array `nums` with `n` objects colored red, white, or blue, sort them **in-place** so that objects of the same color are adjacent, with the colors in the order red, white, and blue.
#
# We will use the integers `0`, `1`, and `2` to represent the color red, white, and blue, respectively.
#
# You must solve this problem without using the library's sort function.
#
# **Example 1:**
# ```
# Input: nums = [2,0,2,1,1,0]
# Output: [0,0,1,1,2,2]
# ```
#
# **Example 2:**
# ```
# Input: nums = [2,0,1]
# Output: [0,1,2]
# ```
#
# **Constraints:**
# - `n == nums.length`
# - `1 <= n <= 300`
# - `nums[i]` is either `0`, `1`, or `2`.

# %% [markdown]
# ## Approach 1: Brute Force (Counting Sort)
#
# **Intuition:** Count the occurrences of 0s, 1s, and 2s, then overwrite the array with the correct counts.
#
# **Algorithm:**
# 1. Count occurrences of each color (0, 1, 2)
# 2. Overwrite the array: first with 0s, then 1s, then 2s

# %%
# Brute Force Solution - Counting Sort
class Solution:
    def sortColors(self, nums: list[int]) -> None:
        """
        Do not return anything, modify nums in-place instead.
        """
        count0 = nums.count(0)
        count1 = nums.count(1)
        count2 = nums.count(2)
        
        idx = 0
        for _ in range(count0):
            nums[idx] = 0
            idx += 1
        for _ in range(count1):
            nums[idx] = 1
            idx += 1
        for _ in range(count2):
            nums[idx] = 2
            idx += 1

# %% [markdown]
# **Complexity Analysis (Brute Force):**
# - Time: O(n) - Two passes through the array
# - Space: O(1) - Only using constant extra space for counters

# %% [markdown]
# ---
# ## Approach 2: Optimal - Dutch National Flag Algorithm
#
# **Intuition:** Use three pointers to partition the array into three sections in a single pass:
# - Elements before `low` are 0s (red)
# - Elements between `low` and `mid` are 1s (white)
# - Elements after `high` are 2s (blue)
#
# This algorithm, proposed by Edsger W. Dijkstra, is named after the flag of the Netherlands which has three stripes.
#
# **Algorithm:**
# 1. Initialize `low = 0`, `mid = 0`, `high = n - 1`
# 2. While `mid <= high`:
#    - If `nums[mid] == 0`: swap with `nums[low]`, increment both `low` and `mid`
#    - If `nums[mid] == 1`: just increment `mid`
#    - If `nums[mid] == 2`: swap with `nums[high]`, decrement only `high` (don't increment mid as swapped element needs checking)

# %%
# Optimal Solution - Dutch National Flag Algorithm
class Solution:
    def sortColors(self, nums: list[int]) -> None:
        """
        Do not return anything, modify nums in-place instead.
        """
        low, mid, high = 0, 0, len(nums) - 1
        
        while mid <= high:
            if nums[mid] == 0:
                nums[low], nums[mid] = nums[mid], nums[low]
                low += 1
                mid += 1
            elif nums[mid] == 1:
                mid += 1
            else:  # nums[mid] == 2
                nums[mid], nums[high] = nums[high], nums[mid]
                high -= 1
                # Don't increment mid here, need to check the swapped element

# %% [markdown]
# **Complexity Analysis (Optimal):**
# - Time: O(n) - Single pass through the array
# - Space: O(1) - Only using constant extra space for pointers

# %% [markdown]
# ## Summary
#
# | Approach | Time | Space | Passes |
# |----------|------|-------|--------|
# | Counting Sort | O(n) | O(1) | 2 |
# | Dutch National Flag | O(n) | O(1) | 1 |
#
# The Dutch National Flag algorithm is preferred as it completes in a single pass while maintaining O(1) space.
